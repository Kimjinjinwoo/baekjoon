# %%
T = int(input())
for _ in range(T):
    N = int(input())
    applicants = [list(map(int, input().split())) for _ in range(N)]

# %%
1 4
2 3
3 2
4 1
5 5
# 우선 이렇게 정렬 하고
# 면접점수 뭐 있었는지 혹은 가장 높은 등수 저장 해 놨다가 비교만 해도 될듯!!
# 내일 구현해보자~

4 1
3 2
2 3
1 4
5 5

# %%
3 2 O
1 4 O
4 1 O
2 3 O
5 5 X

# %%
3 6 X
7 3 X
4 2 O
1 4 O
5 7 X
2 5 X
6 1 O
