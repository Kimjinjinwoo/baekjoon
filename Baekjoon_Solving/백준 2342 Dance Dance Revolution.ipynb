# %%
from sys import maxsize

def get_input():
    return list(map(int, input().split()))

def one_step():
    next_dp = [maxsize] * 4

    for ii in range(4):
        ## 흠... 지금 상태에서 다음 상태로 가는 함수 만들어야 겠다.
        ## (previous_construction, jj) -> (instruction, ii)
        for jj in range(4):
            ## 불가능한 경우 (두 발이 한 곳에 있는 경우)
            if jj == previous_instruction:
                continue





# 지시사항이 주어졌을 때 가질수 있는 state는 3개
        # ex)   지시사항 = 1
        #       가질 수 있는 state = {(1, 2), (1, 3), (1, 4)}
        # 이걸로 dp짜면 되겠다.
if __name__ == "__main__":
    # 입력 받기
    instruction_list = get_input()

    previous_instruction = 0
    dp = [maxsize] * 4
    for instruction in instruction_list[:-1]:

        previous_instruction = instruction
        pass

# %%
4*3*2*1 // (2)
# Out:
# 12
