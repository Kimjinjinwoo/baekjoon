# %%
#2822

Nums = [[i , int(input())] for i in range(8) ]

Nums.sort(key = lambda x : -1 * x[1])

Vals= [ x[1] for x in Nums[:5] ]

print( sum(Vals) )

Idxs = [ str(x[0]+1) for x in Nums[:5] ]

Idxs.sort()

print(" ".join(Idxs))
