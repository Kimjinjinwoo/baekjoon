# %%
def sol(x, y, c):
    ## 이분탐색으로 근사값이라도 찾을까;;;
    print(binarySearch(x,y,c))
    return

def binarySearch(x,y,c):
    a = 0; b = min(x,y)
    for _ in range(100000):
        w = (a+b) / 2
        value = calc(x,y,c,w)
        if value < 0:
            if c - y*(1-c/x) <0:
                a = w
            else:
                b = w
        else:
            if c - y*(1-c/x) <0:
                b = w
            else:
                a = w
    return w

def calc(x,y,c,w):
    return c - (1 - ( c /  ( (x**2 - w**2)**(1/2) ))  ) * (y**2 - w**2)**(1/2)

x,y,c = map(float ,input().split())
sol(x,y,c)
# Out:
# 30000 40000 10000
# 26032.87754423185

# %%
c = X*(Y-c)
if (w == 0):
    c = x(y-c)
    c - x(y-c) >0 -> 0보다 작으면 a = w
    c - x(y-c) <0 -> 0보다 작으면 b = w

# %%
x,y,c = 30,40,10
w = 0
print(calc(x,y,c,15))
print( c - y*(1-c/x) )
# Out:
# -12.80851179251706
# -16.66666666666667

# %%
(x**2 - w**2)**(1/2) : c = w : w2
(y**2 - w**2)**(1/2) : c = w : w1 

c * w = w2 * (x**2 - w**2)**(1/2) = w1 * (y**2 - w**2)**(1/2)
w2 = c * w / ( (x**2 - w**2)**(1/2) )
c * w = (w - w2) * (y**2 - w**2)**(1/2)
      = (w - c * w / ( (x**2 - w**2)**(1/2) ) ) * (y**2 - w**2)**(1/2)

c = (1 - c / ( (x**2 - w**2)**(1/2) )) * (y**2 - w**2)**(1/2)
c = Y - c*Y / X
c*X= XY - c*Y
c*X = Y(X - c) 
c*X+c*Y = X*Y

# %%
w1*X + w2*Y = w*X + w*Y - 2*w*c
0 = w2*X + w1*Y - 2*w*c

# %%
c = Y*(1-c/X)
if (w == 0):
    c = y*(1-c/x)
    c - y*(1-c/x) >0 -> 0보다 작으면 a = w
    c - y*(1-c/x) <0 -> 0보다 작으면 b = w
# Out:
#   File "<ipython-input-1-b6e529eb5e96>", line 1
#     c - (1 - c /  ( (x**2 - w**2)**(1/2) )) * (y**2 - w**2)**(1/2) = 0
#     ^
# SyntaxError: cannot assign to operator

# %%
w*c = w * ()
