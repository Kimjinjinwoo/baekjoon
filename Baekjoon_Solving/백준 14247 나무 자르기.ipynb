# %%
def sol(n, Hi, Ai):
    total = 0
    total += sum(Hi)
    Ai.sort()
    for i in range(n):
        total += Ai[i] * (i)
    print(total)
    return

n = int(input())
Hi = list(map(int, input().split()))
Ai = list(map(int, input().split()))
sol(n, Hi, Ai)
# Out:
# 5
# 1 3 2 4 6
# 2 7 3 4 1
# 64

# %%
5
