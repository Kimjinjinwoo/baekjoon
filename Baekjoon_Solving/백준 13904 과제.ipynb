# %%
import sys
input = sys.stdin.readline

def sol(N, assignments):
    day = [[] for _ in range(1001)]
    total = 0
    for assignment in assignments:
        d, score = assignment
        day[d].append(score)
    # heap으로 구현해도 좋겠다.
    lasts = []
    for i, scores_of_the_day in enumerate(day[::-1]):
        if i == 1000:
            break
        lasts.extend(scores_of_the_day)
        if lasts:
            score = max(lasts)
            total += score
            lasts.remove(score)
            #print(score,lasts)
    print(total)

N = int(input())
assignments = [tuple(map(int, input().split())) for _ in range(N)]

sol(N, assignments)
# Out:
# 185

# %%
sol(N, assignments)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a954f4594822> in <module>
# ----> 1 sol(N, assignments)
#
# <ipython-input-4-3b7d98373320> in sol(N, assignments)
#       8     lasts = []
#       9     for scores_of_the_day in day[::-1]:
# ---> 10         lasts.extedn(scores_of_the_day)
#      11         if lasts:
#      12             score = max(lasts)
#
# AttributeError: 'list' object has no attribute 'extedn'

# %%
a = [3,3,3]
a.remove(3)
print(a)
b = [2,2]
a.extend(b)
print(a)
# Out:
# [3, 3]
# [3, 3, 2, 2]

# %%
N = int(input())
assignments = [tuple(map(int, input().split())) for _ in range(N)]
