# %%
### DFS로 계속 돌려서
### 그래프 몇개 나오는지 하면 될려나..?
def get_data():
    N, M = map(int, input().split())
    graph = [input().strip() for _ in range(N)]

    return N, M, graph

def get_char2direction():
    char2direction = {}
    char2direction['D'] = (-1, 0)
    char2direction['U'] = (1, 0)
    char2direction['L'] = (0, -1)
    char2direction['R'] = (0, 1)

    return char2direction



if __name__ == "__main__":
    ### 입력 받기
    N, M, graph = get_data()
    visited = [[False] * M for _ in range(N)]


    pass
# Out:
# 1 1
# E
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-1fc603872c68> in <cell line: 15>()
#      15 if __name__ == "__main__":
#      16     ### 입력 받기
# ---> 17     N, M, graph = get_data()
#      18     visited = [[False] * M for _ in range(N)]
#      19
#
# TypeError: cannot unpack non-iterable NoneType object
