# %%
N, M = map(int, input().split())
memoryList = list(map(int, input().split()))
costList = list(map(int, input().split()))
# Out:
# 5 60
# 30 10 20 35 40
# 3 0 3 5 4

# %%
from sys import maxsize
def sol(N, M, memoryList, costList):
    ## 합이 M 이상인 것 중에서
    ## cost가 가장 작은 거
    ## 기존의 냅색은 합이 M 이하인 것 중에서, value가 가장 높은 거
    ## 근데 M이 10000000 (천만)인디

    ## 제외하는 것들 고르기
    dp = [0] + [maxsize] * (M)
    for memory, cost in zip(memoryList, costList):
        for ii in range(M+1):
            if ii + memory > M:
                dp[M] = min(dp[ii] + cost, dp[M])
            else:
                dp[ii+memory] = min(dp[ii] + cost, dp[ii+memory])
    print(dp)

sol(N, M, memoryList, costList)
# Out:
# [0, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 0, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 0, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 0, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 5, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 0, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 5, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372036854775807, 0, 9223372036854775807, 9223372036854775807, 9223372036854775807, 9223372
# ...

# %%
maxsize
# Out:
# 9223372036854775807

# %%
def sol(N, M, memoryList, costList):
    ## 합이 M 이상인 것 중에서
    ## cost가 가장 작은 거
    ## 기존의 냅색은 합이 M 이하인 것 중에서, value가 가장 높은 거
    ## 근데 M이 10000000 (천만)인디

    ## sum(memoryList) - M 으로 냅색하자
    ## 제외하는 것들 고르기
    M = sum(memoryList) - M
    dp = [0] * (M+1)
    for memory, cost in zip(memoryList, costList):
        next_dp = dp[:]
        for ii in range(M+1):
            if ii + memory > M:
                break
            next_dp[ii+memory] = max(dp[ii] + cost, dp[ii+memory])
        dp = next_dp
    #print(dp)
    print(sum(costList) - max(dp))
    return

N, M = map(int, input().split())
memoryList = list(map(int, input().split()))
costList = list(map(int, input().split()))

sol(N, M, memoryList, costList)
# Out:
# 6

# %%
sum(memoryList)
# Out:
# 135

# %%
135 - 60
# Out:
# 75
