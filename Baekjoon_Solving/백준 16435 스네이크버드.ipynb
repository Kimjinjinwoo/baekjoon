# %%
#16435

Many , leng = map(int , input().split())

Fruits = list(map(int, input().split()))

Fruits.sort()

for fruit in Fruits:

    if fruit <= leng:

        leng+=1

    else:

        break

print(leng)
