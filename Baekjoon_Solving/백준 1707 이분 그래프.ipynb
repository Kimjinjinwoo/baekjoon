# %%
def sol(V, E, edges):
    verteces = [0] * (V+1)
    
    return

K = int(input())
for _ in range(K):
    V, E = map(int, input().split())
    edges = [tuple(map(int, input().split())) for _ in range(E)]
    sol(V, E, edges)
