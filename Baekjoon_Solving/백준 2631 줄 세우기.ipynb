# %%
def sol(N, nums):
    head = nums[0]
    
    cnt = 0


    return


N = int(input())
nums = [int(input()) for _ in range(N)]

# %%
N = 7
nums = [3, 7, 5, 2, 6, 1, 4]
mydp = [[0, 2],
        [0, 5],
        [1, 3],
        [3, 1],
        [1, 2],
        [5, 0],
        [3, 0]]
