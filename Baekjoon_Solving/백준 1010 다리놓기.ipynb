# %%
import sys

N = int(sys.stdin.readlin())

cases = []

for _ in range(N):      
    case = list(map(int , sys.stdin.readlin().split()))
    cases.append(case)

def combi(N,M):
    son = 1
    mother = 1
    for j in range(1,N+1):
        mother *= (M-N+j) / j
    return (mother)

for N,M in cases:
    print(int(combi(N,M)))
# Out:
# 3
# 2 2
# 1 5
# 13 29
# 1
# 5
# 67863915

# %%
import sys

N = int( input() )
nums = []

for i in range(N):
    nums.append(int(input()))

nums.sort()
#1
avg = sum(nums) / N
print("%0.0f" %avg)

#2
print(nums[N//2])
 
#3

b = nums[0] ; k =0 ; most = []; maxi = 0

for i in nums:
    if i == b:
        k += 1
    else:
        if k > maxi:
            maxi = k
            most=[b]
        elif k == maxi:
            most.append(b)
        else:
            pass
        k = 1
    b = i
    #print( k , maxi , most) 

if k > maxi:
    maxi = k
    most=[b]
elif k == maxi:
    most.append(b)
else:
    pass

if len(most) == 1:
    print(most[0])
else:
    most.sort()
    print(most[1])

#4
print(nums[-1] - nums[0])
# Out:
# 9
# 1
# 1
# 5
# 5
# 5
# 1
# 1
# 5
# 1
# 3
# 1
# 1
# 4

# %%
4
