# %%
import sys
input = sys.stdin.readline

N = int(input())
#dp = [0,1,1]

def sol(N):
    if N == 1:
        print(0)
        return
    else:
        ans = 2 * 3 ** (N-2)
        print(ans % 1000000009)

sol(N)
# Out:
# 1
# 0

# %%
0 1 2
# Out:
# [4, 4, 4]

# %%
for i in range(1,N):
        print(dp)
        next()
    print(dp)
    print(dp[0] % 1000000009)
    return

def next():
    temp_0 = dp[0] + dp[1] + dp[2] 
    temp_1 = dp[1] + dp[2] + dp[0]
    temp_2 = dp[2] + dp[1] + dp[0]
    dp[0] = temp_0
    dp[1] = temp_1
    dp[2] = temp_2
