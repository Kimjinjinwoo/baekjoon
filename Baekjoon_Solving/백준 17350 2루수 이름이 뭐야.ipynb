# %%
import sys
input = sys.stdin.readline

def sol():
    N = int(input())
    names = [input().strip() for _ in range(N)]

    for name in names:
        if name == 'anj':
            print('뭐야;')
            break
    else:
        print('뭐야?')

sol()
# Out:
# 2
# anj
# dkf
# 뭐야;
