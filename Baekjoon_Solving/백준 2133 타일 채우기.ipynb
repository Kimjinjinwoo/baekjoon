# %%
N = int(input())

ans = 0
dp = [3]


# 이게 맞나,,,,,
def go(n):
    mul = [3,2]
    ans = 2
    for i in range(n):
        ans += dp[i] * mul[ min(1 , n-i-1) ] 
    dp.append(ans)

for n in range(1, (N-1)//2 + 1):
    go(n)

print(dp[-1])
# Out:
# 10
# 571

# %%
dp
# Out:
# [3, 11, 41, 153]

# %%
3*2 + 11*2 + 41*3 + 2
# Out:
# 153

# %%
153 * 3 +3 *2 + 11*2 + 41 * 2 + 2
# Out:
# 571

# %%
N = int(input())

ans = 0
dp = [3]

def go(n):
    mul = [3,2]
    ans = 2
    for i in range(n):
        ans += dp[i] * mul[ min(1 , n-i-1) ] 
    dp.append(ans)

for n in range(1, (N-1)//2 + 1):
    go(n)

if N % 2 == 0:
    print(dp[-1])
else:
    print(0)
# Out:
# 4
# 11

# %%
1
# Out:
# 1
