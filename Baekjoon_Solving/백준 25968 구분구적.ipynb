# %%
n = int(input())

# %%
### polynomial에 exp작은 순으로 저장하기
def calc_poly(x : int, poly : int) -> int:
    ans = 0;
    for ii, coef in poly:
        ans += coef * (x ** ( (ii) * 2) )
    return ans

def binary_search():
    return
