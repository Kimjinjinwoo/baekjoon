# %%
T = int(input())

rooms = [int(input()) for _ in range(T)]

def find(room):
    n = room
    all = [0 for _ in range(n+1)]

    for i in range(1,n+1):
        for j in range(i , n+1 , i):
            now = all[j]
            if now:#1
                all[j] = 0
            else:
                all[j] = 1
    print(sum(all))

for room in rooms:
    find(room)
# Out:
# 2
# 5
# 100
# 2
# 10

# %%
rooms
# Out:
# [5, 100]
