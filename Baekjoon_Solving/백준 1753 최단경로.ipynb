# %%
# 쓰브레 다시짜~
import math

V , E = map(int , input().split())
K = int(input())

graphs = [ [i] for i in range(V+1)]
weights = [{i : 0} for i in range(V+1)]
dp = [math.inf for _ in range(V+1)]

for _ in range(E):
    u,v,w = map(int, input().split())
    graphs[u].append(v)
    graphs[v].append(u)

    weights[u][v] = w
    weights[v][u] = w

#BFS로 해볼까
queue = [K]
dp[K] = 0

while queue:
    queue_2 = queue[:]
    n = len(queue_2)
    for i in range(n):
        now = queue_2.pop(0)
        now_leng = dp[now]
        graph_now = graph[now][:]
        for _ in range(len(graph[now])):
            go_dot = graph[now].pop()
# Out:
# s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-b7a6f6398f6d> in <module>()
#       2 import math
#       3
# ----> 4 V , E = map(int , input().split())
#       5 K = int(input())
#       6
#
# ValueError: invalid literal for int() with base 10: 's'
