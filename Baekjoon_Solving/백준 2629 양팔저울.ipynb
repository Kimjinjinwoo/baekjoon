# %%
N = int(input())
WeightList = list(map(int, input().split()))
K = int(input())
MarbleList = list(map(int, input().split()))

# %%
def sol(K, Marble, N, WeightList):
    ## 만들수 있는 무개들을 찾고
    ## 구슬 무게 + 만들 수 있는 무게1 = 만들 수 있는 무게2
    ## 또는 구슬 무게 = 만들 수 있는 무게 찾자.
    
    return



        
    return

# %%
[30]

# %%
500 * 30
# Out:
# 15000

# %%
500 * 30 * 30 * 30
# Out:
# 13500000
