# %%
N, E = map(int, input().split())
graph_info = [tuple(map(int, input().split())) for _ in range(E)]
v1, v2 = map(int, input().split())

# %%
## 1~v1~v2~N 이랑 1~v2~v1~N 비교하면 될듯?
def Dijkstra_algorithm(graph, p1, p2):
    visited = [False] * (N+1)
    
    return

def make_graph(N, E, graph_info):
    graph = [ [] for _ in range(N+1) ]
    for p1, p2, d in graph_info:
        graph[p1].append( (p2, d) )
        graph[p2].append( (p1, d) )
    return graph

def main(N, E, graph_info, v1, v2):
    graph = make_graph(N, E, graph_info)
    start_v1 = Dijkstra_algorithm(graph, 1, v1)
    start_v2 = Dijkstra_algorithm(graph, 1, v2)
    v1_v2 = Dijkstra_algorithm(graph, v1, v2)
    end_v1 = Dijkstra_algorithm(graph, N, v1)
    end_v2 = Dijkstra_algorithm(graph, N, v2)

    return
