# %%
N = int(input())
trans = {}
trans['A'] = 1
trans['Un'] = -1

my_list_like_queue = [trans[input()] for _ in range(N)]

S = 0

for num in my_list_like_queue:
    S += num
    if S < 0:
        break

if S == 0:
    print('YES')
else:
    print('NO')
# Out:
# 1
# Un
# NO
