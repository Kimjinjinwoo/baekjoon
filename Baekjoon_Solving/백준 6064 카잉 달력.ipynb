# %%
def sol():
    T = int(input())
    for _ in range(T):
        pass

## 최소 공배수가 마지막 해임~

def find_year(M,N,x,y):
    return

# %%
"""
M = 3, N = 5
1 1 1
2 2 2
3 3 3
1 4 4
2 5 5    ## 3으로 나눴을 때 나머지가 2고 5로 나눴을 때 나머지가 0인 수 
3 1 6
1 2 7
2 3 8
3 4 9
1 5 10 
2 1 11
3 2 12
1 3 13
2 4 14
3 5 15
"""
