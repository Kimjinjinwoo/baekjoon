# %%
A = input().strip()
B = input().strip()

# %%
def sol(A, B):
    ans = 0
    idxs = fit_idxs(A, B)

    for idx in idxs:
        continue
   
    A = A[::-1] + 'B'
    idxs2 = fit_idxs(A2, B)

    for idx in idxs2:
        

    return

def fit_idxs(A, B):
    idxs = []
    lenA = len(A); lenB = len(B)
    for ii in range(lenB - lenA + 1):
        for jj in range(lenB):
            if A[jj] != B[ii + jj]:
                break
        else:
            idxs.append(ii)
    return idxs
