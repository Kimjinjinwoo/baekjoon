# %%
A = input().strip()
B = input().strip()

# %%
def sol(A, B):
    ans = 0
    idxs = fit_idxs(A, B)
    
    if not idxs:
        print(0)
        return
    
    for idx in idxs:
        

    
    return

def fit_idxs(A, B):
    idxs = []
    lenA = len(A); lenB = len(B)
    for ii in range(lenB - lenA + 1):
        for jj in range(lenB):
            if A[jj] != B[ii + jj]:
                break
        else:
            idxs.append(ii)
    return idxs
