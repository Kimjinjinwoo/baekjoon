# %%
def sol(N, H):
    total = sum(H)
    two_count = 0;one_count = 0
    for h in H:
        if h % 2 == 1:
            one_count += 1
            two_count += h - 1
        else:
            two_count += h 
    
    two_count -= one_count * 2

    if two_count % 3 == 0 and two_count >= 0:
        print('YES')
    else:
        print('NO')
N = int(input())
H = list(map(int, input().split()))
sol(N, H)
# Out:
# 5
# 1 3 1 3 1
# NO
