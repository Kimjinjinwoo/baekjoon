# %%
import os

# %%
rootPath = '/content/drive/MyDrive/AI/AlbumCover/Sample/256_imgs/train/'
total = 0
for genre in ['발라드', '트로트', '힙합']:
    os.chdir(rootPath + genre)
    total += len(os.listdir())
    print(total)
print()
print(total)
# Out:
# 13726
# 29082
# 44206
#
# 44206

# %%
rootPath = '/content/drive/MyDrive/AI/AlbumCover/Sample/256_imgs/vali/'
total = 0
for genre in ['발라드', '트로트', '힙합']:
    os.chdir(rootPath + genre)
    total += len(os.listdir())
    print(total)
print()
print(total)

# %%
44082

12/02
44206

12/10
44206
