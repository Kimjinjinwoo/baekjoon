# %%
def get_data():
    N = int(input())
    power_plant = [list(map(int,input().split()))]
    state = input()
    P = int(input())
    return N, power_plant, state, P

def add(N, num):
    return N | (1 << num)

def check(N, num):
    return True if N & (1 << num) else False

def state2binary(state):
    binary_state = 0
    for ii, X in enumerate(state):
        binary_state += 2**ii if X == 'Y' else 0
    return binary_state

def solve():

    return

if __name__ == "__main__":
    #N, power_plant, state, P = get_data()
    state = state2binary( state )
    dp = {}

# %%
A = state2binary('YNN')
# Out:
# 1
# 0
# 1
# 1
# 1
# 2

# %%
print(A)
# Out:
# 1
