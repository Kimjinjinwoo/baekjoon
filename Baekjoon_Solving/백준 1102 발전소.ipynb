# %%
def get_data():
    N = int(input())
    power_plant = [list(map(int,input().split()))]
    state = input()
    P = int(input())
    return N, power_plant, state, P

if __name__ == "__main__":
    N, power_plant, state, P = get_data()
