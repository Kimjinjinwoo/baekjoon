# %%
N, M = map(int , input().split())
know = list(map(int, input().split()))
parties = [list(map(int , input().split())) for _ in range(M)]

praph = [[] for _ in range(N+1)]
can_lie = [1] * M
cases = []


def make_graph():
    for i , party in enumerate(parties):
        for person in party[1:]:
            graph[i].append(person)

def make_can_lie():
    for know_person in know:
        for cant_party in graph[know_person]:
            can_lie[cant_party] = 0

def sol(graph , can_lie , i):
    for i in range(M)
